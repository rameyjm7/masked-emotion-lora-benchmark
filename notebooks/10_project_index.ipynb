# %% [markdown]
# # 00 Project Index
#
# Workspace index for the LoRA emotion project. This notebook only helps navigation and run order.

# %%
# Cell 0: Define project paths.
from pathlib import Path

PROJECT_ROOT = Path('/home/rameyjm7/workspace/llamafactory-gemma-lora')
NOTEBOOKS_DIR = PROJECT_ROOT / 'notebooks'
DOCS_DIR = PROJECT_ROOT / 'docs'
CONFIGS_DIR = PROJECT_ROOT / 'configs'
OUTPUTS_DIR = PROJECT_ROOT / 'outputs'

for p in [PROJECT_ROOT, NOTEBOOKS_DIR, DOCS_DIR, CONFIGS_DIR, OUTPUTS_DIR]:
    print(p, '->', p.exists())

# %%
# Cell 1: Show run order and notebook inventory.
run_order = [
    '20_baseline_reproduction_runner.ipynb',
    '30_sanity_check_roberta_baseline.ipynb',
    '54_gemma2_2b_lora_pipeline.ipynb',
    '50_roberta_mlm_lora_template.ipynb',
    '51_mental_roberta_mlm_lora.ipynb',
    '52_flan_seq2seq_lora.ipynb',
    '53_llama31_8b_lora_pipeline.ipynb',
    '60_multi_model_comparison.ipynb',
]

for i, name in enumerate(run_order, start=1):
    p = NOTEBOOKS_DIR / name
    print(f'{i}. {name}  (exists={p.exists()})')

\n
